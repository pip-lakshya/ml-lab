# %%
# !pip install matplotlib numpy

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
arrx=np.array([1,2,3,4,5])
arry=np.array([10,20,30,40,50])

# %%
plt.plot(arrx,arry)
plt.show()

# %%
arr2d=np.array([[1,2,3,4,5],[15,25,30,45,60]],dtype=int)

# %%
print(arr2d[0])
print(arr2d[1])
# Out:
# [1 2 3 4 5]
# [15 25 30 45 60]

# %%
print("shape of arr2d:",np.shape(arr2d))
# Out:
# shape of arr2d: (2, 5)

# %%
print("shape of arr2d:",arr2d.shape)
# Out:
# shape of arr2d: (2, 5)

# %%
print("dim of arrx:",arrx.ndim)
print("dim of arr2d:",arr2d.ndim)
# Out:
# dim of arrx: 1
# dim of arr2d: 2

# %%
print("size of arrx:",arrx.size)
print("size of arr2d:",arr2d.size)
# Out:
# size of arrx: 5
# size of arr2d: 10

# %%
plt.bar(arr2d[0], arr2d[1])
plt.scatter(arrx,arry,c='r')
plt.show()

# %%
import random

# %%
arrrandom=np.random.randint(1,100,30)
arrind=np.arange(1,31)
arrlin=np.linspace(1,90,30)

# %%
plt.scatter(arrind, arrrandom)
plt.plot(arrind, arrlin,c='r')
plt.show()

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df1=pd.DataFrame({'Name':['A','B','C','D'],'Age':[20,30,40,50]})
df1
# Out:
#   Name  Age
# 0    A   20
# 1    B   30
# 2    C   40
# 3    D   50

# %%
l1=[60,61,62,63,64]
l2=["Lakshya","Lucky","Kushal","Kunal","Kajal"]
df2=pd.DataFrame(l2,index=pd.Index(l1,name="Rollno"),columns=["Name"])
df2
# Out:
#            Name
# Rollno
# 60      Lakshya
# 61        Lucky
# 62       Kushal
# 63        Kunal
# 64        Kajal
